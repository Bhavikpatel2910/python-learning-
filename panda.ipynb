# %%
import panda as pd
# Out:
# Running cells with '.venv (Python 3.13.13)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/DELL/OneDrive/Documents/Desktop/python.py/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
